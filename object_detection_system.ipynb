# %%
import os

os.chdir(r"D:\machine_learning\ObjectDetectionPro")
print(os.getcwd())
print(os.listdir())
# Out:
# D:\machine_learning\ObjectDetectionPro
# ['data', 'detection.log', 'kaggle.json', 'models', 'notebooks', 'outputs', 'src']

# %%
import importlib, src.detector
importlib.reload(src.detector)
from src.detector import ObjectDetector

det = ObjectDetector(confidence_threshold=0.5)

output_frame, results = det.detect_image(
    "data/sample_images/test.jpg.jpeg", 
    save_path="outputs/result.jpg"
)

print(f"\nTotal {len(results)} objects:\n")
for i, r in enumerate(results, 1):
    print(f"  {i}. {r.class_name:20s} -> {r.confidence:.1%} confidence")
# Out:
# 2026-05-29 22:56:40,155 [INFO] Loaded 80 class labels.
# 2026-05-29 22:56:40,157 [INFO] Loading model from: models/ssd_mobilenet_v2/saved_model
# 2026-05-29 22:56:53,559 [INFO] Fingerprint not found. Saved model loading will continue.
# 2026-05-29 22:56:53,561 [INFO] path_and_singleprint metric could not be logged. Saved model loading will continue.
# 2026-05-29 22:56:53,562 [INFO]  Model loaded successfully.
# 2026-05-29 22:56:58,779 [INFO] Found 20 objects in 4979.9ms
# Total 20 objects:
#
#   1. person               -> 71.1% confidence
#   2. person               -> 67.0% confidence
#   3. person               -> 64.0% confidence
#   4. person               -> 62.6% confidence
#   5. person               -> 61.3% confidence
#   6. person               -> 60.8% confidence
#   7. person               -> 60.7% confidence
#   8. car                  -> 60.2% confidence
#   9. person               -> 59.8% confidence
#   10. person               -> 59.6% confidence
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("outputs/result.jpg")

plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis("off")
plt.title(f"Object Detection Result — {len(results)} objects detected", 
          fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()
